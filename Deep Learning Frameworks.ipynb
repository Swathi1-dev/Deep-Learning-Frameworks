# %% [markdown]
# #Theory
#
# 1.  What is TensorFlow 2.0, and how is it different from TensorFlow 1.x?
#
# Ans: TF 2.0 is more user-friendly, eager execution by default, tight Keras integration, simplified APIs.
#
# 2.  How do you install TensorFlow 2.0?
#
# Ans : !pip install tensorflow==2.0
#
# 3.  What is the primary function of the tf.function in TensorFlow 2.0?
#
# Ans: Converts Python functions into TensorFlow graphs for faster execution.
#
# 4.  What is the purpose of the Model class in TensorFlow 2.0?
#
# Ans: Defines, trains, and evaluates neural networks using Keras API.
#
# 5.  How do you create a neural network using TensorFlow 2.0?
#
# Ans: Use tf.keras.Sequential or subclass tf.keras.Model
#
# 6.  What is the importance of Tensor Space in TensorFlow?
#
# Ans: Represents multi-dimensional data; basis for all computations.
#
# 7.  How can TensorBoard be integrated with TensorFlow 2.0?
#
# Ans:Log training with tf.summary and visualize with TensorBoard.
#
# 8.  What is the purpose of TensorFlow Playground?
#
# Ans: Web tool to visualize simple neural networks interactively.
#
# 9.  What is Netron, and how is it useful for deep learning models?
#
# Ans:Model visualization tool for inspecting layers and parameters.
#
# 10.  What is the difference between TensorFlow and PyTorch?
#
# Ans: TF is more production/deployment focused; PyTorch is more flexible and research-friendly.
#
# 11.  How do you install PyTorch?
#
# Ans:pip install torch torchvision torchaudio
#
# 12.  What is the basic structure of a PyTorch neural network?
#
# Ans: Define model (nn.Module), loss, optimizer, and train loop.
#
# 13.  What is the significance of tensors in PyTorch?
#
# Ans: Core data structure; store and compute multi-dimensional data.
#
# 14.  What is the difference between torch.Tensor and torch.cuda.Tensor in PyTorch?
#
# Ans: Tensor is CPU-based, cuda.Tensor is GPU-based.
#
# 15.  What is the purpose of the torch.optim module in PyTorch?
#
# Ans:Provides optimization algorithms (SGD, Adam, etc.).
#
# 16.  What are some common activation functions used in neural networks?
#
# Ans: ReLU, Sigmoid, Tanh, Softmax.
#
# 17.  What is the difference between torch.nn.Module and torch.nn.Sequential in PyTorch?
#
# Ans: nn.Module for custom models; nn.Sequential for simple layer stacks.
#
# 18.  How can you monitor training progress in TensorFlow 2.0?
#
# Ans: Use callbacks (ModelCheckpoint, EarlyStopping, TensorBoard).
#
# 19.  How does the Keras API fit into TensorFlow 2.0?
#
# Ans: Integrated as the high-level API for building/training models.
#
# 20.  What is an example of a deep learning project that can be implemented using TensorFlow 2.0?
#
# Ans: Image classification using CNNs on MNIST/CIFAR-10.
#
# 21.  What is the main advantage of using pre-trained models in TensorFlow and PyTorch?
#
# Ans: Saves time, improves accuracy with transfer learning.

# %%
#Practical

#1. How do you install and verify that TensorFlow 2.0 was installed successfully2

# !pip install tensorflow
import tensorflow as tf
print(tf.__version__)
# Out:
# ...
# 2.19.0

# %%
#2. How can you define a simple function in TensorFlow 2.0 to perform addition2
import tensorflow as tf

def tensadd(a,b):
  add=tf.add(a,b)
  return add

tensadd([1,2,3,4],[3,4,5,6])
# Out:
# <tf.Tensor: shape=(4,), dtype=int32, numpy=array([ 4,  6,  8, 10], dtype=int32)>

# %%
#3. How can you create a simple neural network in TensorFlow 2.0 with one hidden layer?

from tensorflow.keras.layers import Dense,Input
from tensorflow.keras.models import Sequential

model = Sequential()
model.add(Input(shape=(28,28,3)))
model.add(Dense(64, activation='relu'))
model.add(Dense(10))

# %%
#4. How can you visualize the training progress using TensorFlow and Matplotlib?

import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

(x_train,y_train),(x_test,y_test) = mnist.load_data()

model = Sequential([
    Flatten(input_shape=(28,28)),
    Dense(128,activation='relu'),
    Dense(10,activation='softmax')
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

history = model.fit(
    x_train, y_train,
    epochs=20,
    validation_data=(x_test, y_test)
)
history_dict = history.history
print(history_dict.keys())  # Shows available metrics like 'loss', 'val_loss', 'accuracy', etc.

import matplotlib.pyplot as plt

loss = history_dict['loss']
val_loss = history_dict['val_loss']
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo-', label='Training loss')      # 'bo-' = blue dots with lines
plt.plot(epochs, val_loss, 'r^-', label='Validation loss') # 'r^-' = red triangles with lines
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
acc = history_dict.get('accuracy')
val_acc = history_dict.get('val_accuracy')

if acc and val_acc:
    plt.plot(epochs, acc, 'go-', label='Training Accuracy')
    plt.plot(epochs, val_acc, 'ms-', label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8240 - loss: 7.1313 - val_accuracy: 0.8905 - val_loss: 0.4403
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9088 - loss: 0.3797 - val_accuracy: 0.9232 - val_loss: 0.3602
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9273 - loss: 0.2863 - val_accuracy: 0.9314 - val_loss: 0.2975
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9363 - loss: 0.2412 - val_accuracy: 0.9396 - val_loss: 0.2797
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9452 - loss: 0.2188 - val_accuracy: 0.9435 - val_loss: 0.2391
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9505 - loss: 0.1953 - val_accuracy: 0.9444 - val_loss: 0.2568
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9520 - loss: 0.1979 - val_accuracy: 0.9458 - val_loss: 0.2612
# Epoch 8/20
# ...

# %%
#5. How do you install PyTorch and verify the PyTorch installation2

# !pip install torch
import torch
print(torch.__version__)
# Out:
# ...
# 2.8.0+cu126

# %%
#6. How do you create a simple neural network in PyTorch?

# !pip install torch torchvision

import torch
import torch.nn as nn
import torch.optim as optim
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(10, 5)   # Input layer (10 features) → Hidden layer (5 neurons)
        self.relu = nn.ReLU()         # Activation function
        self.fc2 = nn.Linear(5, 1)    # Hidden layer → Output layer (1 output)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x
model = SimpleNN()
criterion = nn.MSELoss()               # Mean Squared Error for regression
optimizer = optim.SGD(model.parameters(), lr=0.01)

for epoch in range(100):
    inputs = torch.randn(16, 10)       # Batch of 16 samples, each with 10 features
    targets = torch.randn(16, 1)       # Corresponding target values

    outputs = model(inputs)
    loss = criterion(outputs, targets)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if epoch % 10 == 0:
        print(f'Epoch {epoch}, Loss: {loss.item():.4f}')
# Out:
# ...
# Epoch 0, Loss: 0.6034
# Epoch 10, Loss: 1.0676
# Epoch 20, Loss: 1.0826
# Epoch 30, Loss: 1.0516
# Epoch 40, Loss: 1.7047
# Epoch 50, Loss: 1.1580
# Epoch 60, Loss: 1.0907
# Epoch 70, Loss: 1.0684
# Epoch 80, Loss: 1.0002
# Epoch 90, Loss: 0.5072

# %%
#7. How do you define a loss function and optimizer in PyTorch2


import torch.nn as nn

# For regression tasks
loss_fn = nn.MSELoss()  # Mean Squared Error

# For binary classification
loss_fn = nn.BCELoss()  # Binary Cross Entropy

# For multi-class classification
loss_fn = nn.CrossEntropyLoss()  # Combines LogSoftmax + NLLLoss

import torch.optim as optim

# Assuming you have a model called 'model'
optimizer = optim.SGD(model.parameters(), lr=0.01)  # Stochastic Gradient Descent

# Other popular choices
optimizer = optim.Adam(model.parameters(), lr=0.001)  # Adaptive Moment Estimation
optimizer = optim.RMSprop(model.parameters(), lr=0.001)  # Root Mean Square Prop

outputs = model(inputs)
loss = loss_fn(outputs, targets)

optimizer.zero_grad()  # Clear previous gradients
loss.backward()        # Backpropagation
optimizer.step()       # Update weights

# %%
#8. How do you implement a custom loss function in PyTorch?

import torch

def custom_loss(output, target):
    # Example: L1 loss + L2 loss
    l1 = torch.abs(output - target)
    l2 = (output - target) ** 2
    return torch.mean(l1 + l2)
loss = custom_loss(predictions, targets)

# %%
#9. How do you save and load a TensorFlow model?

model.save('my_model')  # Creates a folder named 'my_model'
